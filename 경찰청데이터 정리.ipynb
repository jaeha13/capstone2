# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc, font_manager
import re
import seaborn as sns

font_path = './malgun.ttf'
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)
# Out:
# C:\Users\hajae\anaconda3\envs\pydatavenv\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\hajae\anaconda3\envs\pydatavenv\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
# C:\Users\hajae\anaconda3\envs\pydatavenv\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
exc1 = pd.read_excel('경찰청/경찰청데이터.xlsx', sheet_name=0)
exc2 = pd.read_excel('경찰청/경찰청데이터.xlsx', sheet_name=1)
exc3 = pd.read_excel('경찰청/경찰청데이터.xlsx', sheet_name=2)
exc4 = pd.read_excel('경찰청/경찰청데이터.xlsx', sheet_name=3)

# %%
print(exc1.shape, exc2.shape, exc3.shape, exc4.shape)
# Out:
# (64999, 6) (64999, 6) (64999, 6) (37906, 6)

# %%
df = pd.concat([exc1, exc2, exc3, exc4])

# %%
df = df[df['대상구분'] == '아동']

# %%
df['발생지역'].fillna('불상', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101363 entries, 223 to 37905
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   대상구분    101363 non-null  object
#  1   실종나이    101363 non-null  int64
#  2   발생일시    101363 non-null  object
#  3   등록일시    101363 non-null  object
#  4   발견일시    101363 non-null  object
#  5   발생지역    101363 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 5.4+ MB

# %%
df = df[df['실종나이'] <= 10]

# %%
df.value_counts('실종나이')
# Out:
# 실종나이
# 6     2345
# 7     2313
# 10    2232
# 9     1990
# 8     1945
# 5     1420
# 4     1122
# 3      724
# 0      397
# 2      349
# 1      179
# dtype: int64

# %%
pd.set_option('display.max_rows', None)
df.value_counts(df['발생지역'].apply(lambda x: str(x).split()[0]))
# Out:
# 발생지역
# 경기도             4803
# 서울특별시           1818
# 부산광역시           1259
# 경상남도            1025
# 인천광역시            916
# 서울               658
# 경기               367
# 충청남도             327
# 대구광역시            302
# 광주광역시            292
# 대전광역시            287
# 전라남도             278
# 경상북도             263
# 전라북도             238
# 충청북도             188
# 부산               145
# 강원도              141
# 울산광역시            134
# 제주특별자치도          124
# 경남               119
# 대구                99
# 인천                92
# 충남                79
# 광주                70
# 불상                70
# 서울시               62
# 경북                52
# 세종특별자치시           50
# 전남                48
# 전북                45
# 김해시               44
# 대전                41
# 충북                37
# 울산                23
# 진주시               21
# 강원                17
# 평택시               16
# 인천시               12
# 안산시               11
# 대구시                9
# 주소지                9
# 광주시                8
# 안양시                8
# ...

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '광진구', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '광진구', '발생지역'].apply(lambda x: '서울특별시 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '양천구', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '양천구', '발생지역'].apply(lambda x: '서울특별시 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '은평구', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '은평구', '발생지역'].apply(lambda x: '서울특별시 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '강남구', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '강남구', '발생지역'].apply(lambda x: '서울특별시 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '강남', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '강남', '발생지역'].apply(lambda x: '서울특별시 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '서을', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '서을', '발생지역'].apply(lambda x: x.replace('서을', '서울'))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '영등포', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '영등포', '발생지역'].apply(lambda x: '서울특별시 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '금천구', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '금천구', '발생지역'].apply(lambda x: '서울특별시 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '고덕동', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '고덕동', '발생지역'].apply(lambda x: '서울특별시 강동구 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '장지동', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '장지동', '발생지역'].apply(lambda x: '서울특별시 송파구 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '잠실역', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '잠실역', '발생지역'].apply(lambda x: '서울특별시 송파구 잠실동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '자양동', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '자양동', '발생지역'].apply(lambda x: '서울특별시 광진구 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '올림픽공원', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '올림픽공원', '발생지역'].apply(lambda x: '서울특별시 송파구 오륜동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '우림시장', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '우림시장', '발생지역'].apply(lambda x: '서울특별시 중랑구 망우본동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '원효대교', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '원효대교', '발생지역'].apply(lambda x: '서울특별시 영등포구 여의도동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '은평성모병원', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '은평성모병원', '발생지역'].apply(lambda x: '서울특별시 은평구 진관동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '관악구청', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '관악구청', '발생지역'].apply(lambda x: '서울특별시 관악구 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '종로구', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '종로구', '발생지역'].apply(lambda x: '서울특별시 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '오현어린이공원', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '오현어린이공원', '발생지역'].apply(lambda x: '서울특별시 강북구 번동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '혜화동로타리', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '혜화동로타리', '발생지역'].apply(lambda x: '서울특별시 종로구 혜화동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '혜화동에', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '혜화동에', '발생지역'].apply(lambda x: '서울특별시 종로구 혜화동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '화곡동', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '화곡동', '발생지역'].apply(lambda x: '서울특별시 강서구 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '개포4동', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '개포4동', '발생지역'].apply(lambda x: '서울특별시 강남구 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '중구', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '중구', '발생지역'].apply(lambda x: '서울특별시 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '강서구', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '강서구', '발생지역'].apply(lambda x: '서울특별시 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '강동구', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '강동구', '발생지역'].apply(lambda x: '서울특별시 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '타임스퀘어', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '타임스퀘어', '발생지역'].apply(lambda x: '서울특별시 영등포구 영등포동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '특별시', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '특별시', '발생지역'].apply(lambda x: '서울' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '방화동', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '방화동', '발생지역'].apply(lambda x: '서울특별시 강서구 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '답십리로60길', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '답십리로60길', '발생지역'].apply(lambda x: '서울특별시 동대문구 답십리동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '불광동', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '불광동', '발생지역'].apply(lambda x: '서울특별시 은평구 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '상계동', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '상계동', '발생지역'].apply(lambda x: '서울특별시 노원구 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '롯데월드', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '롯데월드', '발생지역'].apply(lambda x: '서울특별시 송파구 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '동대문구', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '동대문구', '발생지역'].apply(lambda x: '서울특별시 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '동작', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '동작', '발생지역'].apply(lambda x: '서울특별시 ' + str(x).split()[1] + '구' + ''.join(str(x).split()[2:]))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '동작동', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '동작동', '발생지역'].apply(lambda x: '서울특별시 동작구' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '마포구', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '마포구', '발생지역'].apply(lambda x: '서울특별시 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '밀알학교(삼성의료원', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '밀알학교(삼성의료원', '발생지역'].apply(lambda x: '서울특별시 강남구 일원동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '목동', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '목동', '발생지역'].apply(lambda x: '서울특별시 양천구 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '몽촌토성', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '몽촌토성', '발생지역'].apply(lambda x: '서울특별시 강동구 성내동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '대도초교', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '대도초교', '발생지역'].apply(lambda x: '서울특별시 강남구 도곡동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '서대문', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '서대문', '발생지역'].apply(lambda x: '서울특별시 ' + str(x).split()[0] + '구 ' + ''.join(str(x).split()[1:]))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '서대문구', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '서대문구', '발생지역'].apply(lambda x: '서울특별시 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '금천', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '금천', '발생지역'].apply(lambda x: '서울특별시 ' + str(x).split()[0] + '구 ' + ''.join(str(x).split()[1:]))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '아현동소재', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '아현동소재', '발생지역'].apply(lambda x: '서울특별시 마포구 아현동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '암사동', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '암사동', '발생지역'].apply(lambda x: '서울특별시 강동구 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '양재동', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '양재동', '발생지역'].apply(lambda x: '서울특별시 서초구 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '구바발역', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '구바발역', '발생지역'].apply(lambda x: '서울특별시 은평구 진관동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '여의나루역', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '여의나루역', '발생지역'].apply(lambda x: '서울특별시 영등포구 여의동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '여의동', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '여의동', '발생지역'].apply(lambda x: '서울특별시 영등포구 여의동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '구로구', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '구로구', '발생지역'].apply(lambda x: '서울특별시 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '휘경파출소', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '휘경파출소', '발생지역'].apply(lambda x: '서울특별시 동대문구 휘경동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '신도림초등학교', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '신도림초등학교', '발생지역'].apply(lambda x: '서울특별시 구로구 신도림동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '신길5동', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '신길5동', '발생지역'].apply(lambda x: '서울특별시 영등포구 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '수유시장', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '수유시장', '발생지역'].apply(lambda x: '서울특별시 강북구 수유동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '수서경찰서부근', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '수서경찰서부근', '발생지역'].apply(lambda x: '서울특별시 강남구 개포동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '금천구청', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '금천구청', '발생지역'].apply(lambda x: '서울특별시 금천구 시흥동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '성북구', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '성북구', '발생지역'].apply(lambda x: '서울특별시 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '서초3파출소로', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '서초3파출소로', '발생지역'].apply(lambda x: '서울특별시 서초구 방배동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '서울숲', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '서울숲', '발생지역'].apply(lambda x: '서울특별시 성동구 성수동 1가 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '서서울호수공원', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '서서울호수공원', '발생지역'].apply(lambda x: '서울특별시 양천구 신월동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '서부이촌동', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '서부이촌동', '발생지역'].apply(lambda x: '서울특별시 용산구 이촌동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '신상도초등학교', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '신상도초등학교', '발생지역'].apply(lambda x: '서울특별시 동작구 상도동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '대림동', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '대림동', '발생지역'].apply(lambda x: '서울특별시 영등포구 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '영신로', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '영신로', '발생지역'].apply(lambda x: '서울특별시 영등포구 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '영등포역', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '영등포역', '발생지역'].apply(lambda x: '서울특별시 영등포구 영등포동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '영등포동4가', '발생지역'] = df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '영등포동4가', '발생지역'].apply(lambda x: '서울특별시 영등포구 영등포동 ' + str(x))

# %%
df.loc[df['발생지역'].apply(lambda x: str(x).split()[0]) == '구로', '발생지역'] = '서울특별시 구로구 개봉동'

# %%
pd.set_option('display.max_rows', None)
df.value_counts(df['발생지역'].apply(lambda x: str(x).split()[0]))
# Out:
# 발생지역
# 경기도             4803
# 서울특별시           1902
# 부산광역시           1259
# 경상남도            1025
# 인천광역시            916
# 서울               661
# 경기               367
# 충청남도             327
# 대구광역시            302
# 광주광역시            292
# 대전광역시            287
# 전라남도             278
# 경상북도             263
# 전라북도             238
# 충청북도             188
# 부산               145
# 강원도              141
# 울산광역시            134
# 제주특별자치도          124
# 경남               119
# 대구                99
# 인천                92
# 충남                79
# 불상                70
# 광주                70
# 서울시               62
# 경북                52
# 세종특별자치시           50
# 전남                48
# 전북                45
# 김해시               44
# 대전                41
# 충북                37
# 울산                23
# 진주시               21
# 강원                17
# 평택시               16
# 인천시               12
# 안산시               11
# 대구시                9
# 주소지                9
# 의정부시               8
# 대전시                8
# ...

# %%
df.to_csv('./result/경찰청데이터_주소정리.csv', index=False, sep=',')

# %%
df_s = df.loc[df['발생지역'].apply(lambda x: str(x)[:2]) == '서울', :]

# %%
df_s.columns
# Out:
# Index(['대상구분', '실종나이', '발생일시', '등록일시', '발견일시', '발생지역'], dtype='object')

# %%
df_s
# Out:
#       대상구분  실종나이              발생일시              등록일시              발견일시  \
# 223     아동     5  1963-01-01 09:00  2015-01-08 17:34  2017-10-19 12:00
# 2954    아동     3  1977-10-15 12:00  2015-03-17 15:20  2017-02-16 00:00
# 13156   아동     3  1977-08-01 12:00  2015-10-02 14:13  2020-10-06 00:00
# 19243   아동     1  2007-12-31 10:00  2016-02-19 18:30  2017-06-26 17:00
# 20483   아동     0  2009-02-01 12:00  2016-03-17 11:21  2018-07-25 00:00
# 24303   아동     3  1987-08-01 12:00  2016-05-27 10:13  2017-09-21 21:00
# 26150   아동     3  1984-06-01 09:30  2016-06-28 17:31  2017-09-11 10:21
# 27928   아동     3  1993-07-01 00:00  2016-07-30 17:27  2017-02-22 17:00
# 29453   아동     2  1977-04-01 00:00  2016-08-26 22:24  2017-04-08 14:11
# 30876   아동     5  1979-07-30 15:00  2016-09-20 12:37  2018-07-26 10:00
# 31678   아동     7  1965-08-01 09:00  2016-10-04 10:10  2017-04-02 00:00
# 32106   아동     0  2005-09-20 19:00  2016-10-12 09:59  2018-08-17 09:50
# ...

# %%
df_s['자치구'] = df_s['발생지역'].apply(lambda x: x.split()[1])
# Out:
# C:\Users\hajae\AppData\Local\Temp/ipykernel_10120/1855898701.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s['자치구'] = df_s['발생지역'].apply(lambda x: x.split()[1])

# %%
df_s.columns
# Out:
# Index(['대상구분', '실종나이', '발생일시', '등록일시', '발견일시', '발생지역', '자치구'], dtype='object')

# %%
df_s.자치구.value_counts()
# Out:
# 관악구           249
# 금천구           174
# 송파구           165
# 영등포구          160
# 은평구           144
# 구로구           137
# 마포구           126
# 강남구           124
# 양천구           112
# 강서구           111
# 광진구            94
# 동대문구           93
# 노원구            92
# 강동구            90
# 강북구            87
# 도봉구            85
# 서초구            81
# 동작구            80
# 성북구            78
# 중랑구            66
# 서대문구           56
# 종로구            44
# 용산구            40
# 성동구            39
# 중구             33
# 영등포             6
# 강남              4
# 송파              3
# 양천              3
# 이하              2
# 노원              2
# 도봉              2
# 종로              2
# 금천              2
# 강서              2
# 동작              2
# 은평              2
# 구로              2
# 독산1동            1
# 신용산             1
# 마포대교            1
# 홀트아동복지회         1
# 소재              1
# 한강공원            1
# 특별시             1
# 장승배기구           1
# 서초구청계산로         1
# 이하불상            1
# 중계역             1
# 서오릉로            1
# ...

# %%
df_s.loc[df_s['자치구'] == '영등포', '자치구'] = '영등포구'
df_s.loc[df_s['자치구'] == '강남', '자치구'] = '강남구'
df_s.loc[df_s['자치구'] == '송파', '자치구'] = '송파구'
df_s.loc[df_s['자치구'] == '양천', '자치구'] = '양천구'
df_s.loc[df_s['자치구'] == '노원', '자치구'] = '노원구'
df_s.loc[df_s['자치구'] == '도봉', '자치구'] = '도봉구'
df_s.loc[df_s['자치구'] == '종로', '자치구'] = '종로구'
df_s.loc[df_s['자치구'] == '금천', '자치구'] = '금천구'
df_s.loc[df_s['자치구'] == '강서', '자치구'] = '강서구'
df_s.loc[df_s['자치구'] == '동작', '자치구'] = '동작구'
df_s.loc[df_s['자치구'] == '은평', '자치구'] = '은평구'
df_s.loc[df_s['자치구'] == '구로', '자치구'] = '구로구'
df_s.loc[df_s['자치구'] == '독산1동', '자치구'] = '금천구'
df_s.loc[df_s['자치구'] == '신용산', '자치구'] = '용산구'
df_s.loc[df_s['자치구'] == '마포대교', '자치구'] = '마포구'
df_s.loc[df_s['자치구'] == '홀트아동복지회', '자치구'] = '마포구'
df_s.loc[df_s['자치구'] == '장승배기구', '자치구'] = '동작구'
df_s.loc[df_s['자치구'] == '서초구청계산로', '자치구'] = '서초구'
df_s.loc[df_s['자치구'] == '중계역', '자치구'] = '노원구'
df_s.loc[df_s['자치구'] == '서오릉로', '자치구'] = '은평구'
df_s.loc[df_s['자치구'] == '강남고속버스터미널', '자치구'] = '서초구'
df_s.loc[df_s['자치구'] == '성동그', '자치구'] = '성동구'
df_s.loc[df_s['자치구'] == '도봉구(現', '자치구'] = '도봉구'
df_s.loc[df_s['자치구'] == '동작구동작동', '자치구'] = '동작구'
df_s.loc[df_s['자치구'] == '도봉구해득로', '자치구'] = '도봉구'
df_s.loc[df_s['자치구'] == '관악', '자치구'] = '관악구'
df_s.loc[df_s['자치구'] == '성동', '자치구'] = '성동구'
df_s.loc[df_s['자치구'] == '동대문', '자치구'] = '동대문구'
df_s.loc[df_s['자치구'] == '광나루한강수영장부근', '자치구'] = '강동구'
df_s.loc[df_s['자치구'] == '강북', '자치구'] = '강북구'
df_s.loc[df_s['자치구'] == '강복구', '자치구'] = '강북구'
df_s.loc[df_s['자치구'] == '한티역', '자치구'] = '강남구'
df_s.loc[df_s['자치구'] == '도곡동', '자치구'] = '강남구'
df_s.loc[df_s['자치구'] == '동작대교', '자치구'] = '용산구'
df_s.loc[df_s['자치구'] == '잠실롯데월드', '자치구'] = '송파구'
df_s.loc[df_s['자치구'] == '성북', '자치구'] = '성북구'
# Out:
# C:\Users\hajae\anaconda3\envs\pydatavenv\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df_s = df_s.loc[(df_s['자치구'] != '이하') & (df_s['자치구'] != '주구') & (df_s['자치구'] != '터미널') & (df_s['자치구'] != '이하불상') & (df_s['자치구'] != '한강공원') & (df_s['자치구'] != '특별시') & (df_s['자치구'] != '소재'), :]

# %%
len(df_s.자치구.value_counts())
# Out:
# 25

# %%
df_s.groupby(['자치구'])[['대상구분']].count().describe()
# Out:
#              대상구분
# count   25.000000
# mean   104.640000
# std     50.647376
# min     33.000000
# 25%     79.000000
# 50%     94.000000
# 75%    130.000000
# max    250.000000

# %%
df_s.to_csv('./result/경찰청데이터_주소정리.csv', index=False, sep=',')
